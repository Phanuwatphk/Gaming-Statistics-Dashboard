# %% [markdown]
# # 🎮 Gaming Statistics Dashboard
# ## Final Term Project — Sprint 1
#
# **รายวิชา:** CP352301 Script Programming
# **ภาคการศึกษา:** 1/2569
# **Sprint:** Sprint 1 — Front-End App Development
# **วันนำเสนอ:** 15–16 September 2026
# **วันส่งงาน:** 18 September 2026

# %% [markdown]
# ---
#
# # Project Pitch
#
# ### ชื่อโปรเจกต์
# **Gaming Statistics Dashboard**
#
# ### ปัญหาที่ต้องการแก้ไข
# ข้อมูลเกี่ยวกับเกม เช่น คะแนน ประเภทเกม แพลตฟอร์ม และข้อมูลการวางจำหน่าย
# มีอยู่เป็นจำนวนมากและกระจายอยู่ในชุดข้อมูลขนาดใหญ่ ทำให้ผู้ใช้งาน
# ค้นหา สำรวจ และเปรียบเทียบข้อมูลเกมได้ไม่สะดวก
#
# ### แนวทางการแก้ปัญหา
# Gaming Statistics Dashboard เป็นแอปพลิเคชันที่พัฒนาด้วย Python
# เพื่อช่วยให้ผู้ใช้งานสามารถค้นหาและสำรวจข้อมูลเกมผ่านส่วนติดต่อ
# ที่เรียบง่ายและเข้าใจได้ง่าย
#
# ใน Sprint 1 โปรเจกต์จะเน้นการพัฒนา **Command Line Interface (CLI)**
# ที่ประกอบด้วยระบบเมนู การรับข้อมูลจากผู้ใช้ การตรวจสอบความถูกต้องของข้อมูล
# การจัดการข้อผิดพลาด และการแสดงข้อมูลเกมพื้นฐาน
#
# ### Domain
# **Data Analysis & Management**
#
# ### แหล่งข้อมูลที่วางแผนจะใช้
#
# ในเวอร์ชันสมบูรณ์ของ Gaming Statistics Dashboard
# มีแผนที่จะใช้ **RAWG Video Games Database API**
# เป็นแหล่งข้อมูลเกมภายนอกหลักของระบบ
#
# RAWG สามารถให้ข้อมูลเกี่ยวกับเกม เช่น:
# - ชื่อเกม
# - Ratings
# - วันวางจำหน่าย
# - Genres
# - Platforms
# - Metacritic scores
# - รูปภาพเกมและข้อมูลที่เกี่ยวข้อง
#
# **RAWG Website:**
# https://rawg.io/
#
# **RAWG API:**
# https://api.rawg.io/
#
# > **หมายเหตุสำหรับ Sprint 1:**
# > ใน Sprint 1 ยังไม่มีการเชื่อมต่อ RAWG API จริง
# > โดยจะใช้ชุดข้อมูลตัวอย่างขนาดเล็กภายในโปรแกรมเพื่อสาธิตการทำงานของ CLI,
# > ระบบเมนู, การค้นหา, Statistics และ Input Validation
# > ส่วนการเชื่อมต่อ API จริงจะพัฒนาใน Sprint ถัดไป

# %% [markdown]
# ---
#
#
# # Sprint 1 — Scope & Project Direction
#
# ## สถาปัตยกรรมที่วางแผนไว้สำหรับ Final Project
#
# RAWG API
# ↓
# Data Processing
# ↓
# SQLite
# ↓
# Statistics & Analysis
# ↓
# User Interface
#
# ### เทคโนโลยีที่วางแผนจะใช้
# - Python
# - RAWG API
# - Pandas
# - SQLite
# - Data Visualization
# - Streamlit
# - pytest
# - GitHub Actions
#
# > เทคโนโลยีข้างต้นเป็นแผนสำหรับ **Final Project**
# > และยังไม่ได้ถูกนำมาใช้งานทั้งหมดใน Sprint 1
#
# ---
#
# ## ขอบเขตของ Sprint 1
#
# Sprint 1 เน้นเฉพาะการพัฒนา:
#
# - Command Line Interface (CLI)
# - ระบบเมนู
# - การรับข้อมูลจากผู้ใช้
# - Input Validation
# - Exception Handling
# - การแสดงข้อมูลเกมพื้นฐาน
# - Local Sample Data
# - QA และ Edge-case Testing
#
# ### ส่วนที่เลื่อนไปพัฒนาใน Sprint ถัดไป
#
# - การเชื่อมต่อ RAWG API จริง
# - File I/O
# - SQLite Persistence
# - ระบบ Search / Filter / Sort ขั้นสูง
# - Pandas Data Processing
# - Data Visualization
# - Streamlit Web Application
# - Automated Testing
# - GitHub Actions / CI/CD

# %% [markdown]
# ---
#
# # Sprint 1 — Plan
#
# ## จุดเน้นของ Sprint 1
# **Front-End App Development — Command Line Interface (CLI)**
#
# ## Sprint Goal
#
# สร้างพื้นฐาน CLI สำหรับ **Gaming Statistics Dashboard**
# ที่สามารถให้ผู้ใช้งานเลือกเมนู ดูข้อมูลเกม ค้นหาเกม
# จัดการข้อมูลนำเข้าที่ไม่ถูกต้องได้อย่างปลอดภัย
# และสามารถออกจากโปรแกรมได้อย่างถูกต้อง
#
# ---
#
# ## บทบาทของสมาชิกในทีม
#
# ### Planner — คิม
#
# หน้าที่:
# - กำหนด Sprint Goal
# - กำหนด Requirements ของโปรเจกต์
# - ออกแบบโครงสร้าง CLI
# - กำหนด Definition of Done
# - แบ่งงานออกเป็น Development Blocks
# - ตรวจสอบความคืบหน้าของ Sprint
#
# ### Coder — ฟลุ๊ค
#
# หน้าที่:
# - พัฒนา Python CLI
# - สร้างระบบเมนูและการนำทาง
# - พัฒนาฟังก์ชันพื้นฐาน
# - จัดการ User Input
# - เขียนฟังก์ชันให้อ่านและเข้าใจง่าย
# - เพิ่ม Docstring ที่เหมาะสม
# - เขียนโค้ดตามแนวทาง PEP 8
#
# ### Debugger — ออม
#
# หน้าที่:
# - ทดสอบ Input ปกติ
# - ทดสอบ Input ที่ไม่ถูกต้อง
# - ทดสอบ Edge Cases
# - บันทึก Expected Result และ Actual Result
# - ตรวจสอบว่า Input ที่ผิดไม่ทำให้โปรแกรมหยุดทำงาน
# - บันทึก Bug และแนวทางแก้ไข
#
# ---
#
# # Sprint 1 Functional Requirements
#
# ### FR-01 — Welcome Screen
# เมื่อเริ่มต้นโปรแกรม ระบบต้องแสดงชื่อโปรเจกต์
#
# ### FR-02 — Main Menu
# ระบบต้องแสดงเมนูดังต่อไปนี้อย่างชัดเจน:
#
# 1. View Games
# 2. Search Game
# 3. View Statistics
# 4. View Genres
# 5. View Top Rated Games
# 0. Exit
#
# ### FR-03 — Menu Input
# ผู้ใช้งานต้องสามารถเลือกเมนูด้วยตัวเลขตั้งแต่ `0–5`
#
# ### FR-04 — Input Validation
# โปรแกรมต้องสามารถจัดการกรณีต่อไปนี้ได้อย่างปลอดภัย:
# - Menu Input ที่ถูกต้อง
# - ตัวเลขที่อยู่นอกช่วงที่กำหนด
# - ตัวเลขติดลบ
# - Input ที่ไม่ใช่ตัวเลข
# - Blank Input
#
# Input ที่ไม่ถูกต้องต้องไม่ทำให้โปรแกรม Crash
#
# ### FR-05 — Search Input
# ฟังก์ชัน Search Game ต้อง:
# - รับชื่อเกมจากผู้ใช้
# - ไม่ยอมรับ Search Input ที่เป็นค่าว่าง
# - รองรับการค้นหาแบบไม่สนตัวพิมพ์เล็ก-ใหญ่
# - แสดงข้อความที่ชัดเจนเมื่อไม่พบเกม
#
# ### FR-06 — Menu Navigation
# หลังจากดำเนินการในแต่ละเมนูเสร็จ
# ระบบต้องกลับไปยัง Main Menu
#
# ### FR-07 — Exit
# เมื่อเลือก `0` โปรแกรมต้องแสดงข้อความอำลา
# และสิ้นสุดการทำงานอย่างถูกต้อง
#
# ---
#
# # Definition of Done
#
# Sprint 1 จะถือว่าเสร็จสมบูรณ์เมื่อ:
#
# - [x] CLI สามารถเริ่มทำงานได้สำเร็จ
# - [x] แสดง Welcome Message ได้
# - [x] แสดง Main Menu ได้ชัดเจน
# - [x] เมนูที่ถูกต้องสามารถทำงานได้
# - [x] รองรับหมายเลขเมนูที่ไม่ถูกต้อง
# - [x] รองรับตัวเลขติดลบ
# - [x] Input ที่ไม่ใช่ตัวเลขไม่ทำให้โปรแกรม Crash
# - [x] รองรับ Blank Menu Input
# - [x] มีการตรวจสอบ Search Input
# - [x] รองรับ Case-insensitive Search
# - [x] รองรับกรณีค้นหาเกมที่ไม่มีในข้อมูล
# - [x] หลังจากทำงานเสร็จสามารถกลับ Main Menu ได้
# - [x] Exit Option ทำงานถูกต้อง
# - [x] แต่ละฟังก์ชันมีหน้าที่ชัดเจน
# - [x] ฟังก์ชันสำคัญมี Docstring
# - [x] มีการจัดทำ QA Test Cases
# - [x] มี Sprint Retrospective
# - [x] Code พร้อมสำหรับการส่งขึ้น GitHub

# %% [markdown]
# ---
#
# # Sprint 1 — Blocks
#
# ## Block 1 — CLI Foundation
# - Welcome Screen
# - Main Menu
# - Menu Input
# - Main Application Loop
# - Safe Exit
#
# ## Block 2 — Menu Features
# - View Games
# - Search Game
# - View Statistics
# - View Genres
# - View Top Rated Games
# - Sprint 1 Local Sample Dataset
#
# ## Block 3 — Input Validation & Error Handling
# - Blank Input
# - Non-numeric Input
# - Invalid Menu Range
# - Negative Input
# - Empty Search
# - Unknown Game
# - Case-insensitive Search
#
# ## Block 4 — QA & Sprint Validation
#
# Debugger จะทดสอบทั้งหมด 14 กรณี ครอบคลุม:
#
# - การเริ่มต้นโปรแกรม
# - ฟังก์ชันเมนูทั้ง 5 รายการ
# - การค้นหาเกมแบบปกติและ Case-insensitive
# - Invalid Numeric Input
# - Negative Input
# - Text Input
# - Blank Menu Input
# - Empty Search
# - Unknown Game
# - Safe Exit

# %% [markdown]
# ---
#
# # Sprint 1 — Complete CLI Code

# %%
# Sprint 1 Local Sample Dataset
games = [
    {
        "name": "Portal 2",
        "rating": 4.6,
        "genre": "Puzzle",
        "platform": "PC",
    },
    {
        "name": "The Witcher 3",
        "rating": 4.8,
        "genre": "RPG",
        "platform": "PC",
    },
    {
        "name": "Minecraft",
        "rating": 4.5,
        "genre": "Sandbox",
        "platform": "Multi-platform",
    },
    {
        "name": "Hades",
        "rating": 4.7,
        "genre": "Action",
        "platform": "Nintendo Switch",
    },
    {
        "name": "God of War",
        "rating": 4.7,
        "genre": "Action",
        "platform": "PlayStation",
    },
    {
        "name": "Stardew Valley",
        "rating": 4.4,
        "genre": "Simulation",
        "platform": "PC",
    },
    {
        "name": "Mario Kart 8 Deluxe",
        "rating": 4.5,
        "genre": "Racing",
        "platform": "Nintendo Switch",
    },
    {
        "name": "Baldur's Gate 3",
        "rating": 4.9,
        "genre": "RPG",
        "platform": "PC",
    },
]


def display_welcome_message():
    """Display the application title in a readable banner."""
    print("=" * 60)
    print("             GAMING STATISTICS DASHBOARD")
    print("=" * 60)


def display_main_menu():
    """Display the available menu options."""
    print("\n1. View Games")
    print("2. Search Game")
    print("3. View Statistics")
    print("4. View Genres")
    print("5. View Top Rated Games")
    print("0. Exit")


def get_menu_choice():
    """Read and validate a menu choice from 0 to 5."""
    user_input = input("\nSelect an option: ").strip()

    if not user_input:
        print("Warning: Please enter a menu option from 0 to 5.")
        return None

    try:
        choice = int(user_input)
    except ValueError:
        print("Warning: Menu choice must be a number from 0 to 5.")
        return None

    if choice < 0 or choice > 5:
        print("Warning: Please select a menu option from 0 to 5.")
        return None

    return choice


def view_games():
    """Display every game in the local sample dataset."""
    print("\nGAMES")
    print("-" * 72)

    for number, game in enumerate(games, start=1):
        print(
            f"{number}. {game['name']} | "
            f"Rating: {game['rating']:.1f} | "
            f"Genre: {game['genre']} | "
            f"Platform: {game['platform']}"
        )


def search_game():
    """Search for games using a case-insensitive partial name."""
    search_term = input("\nEnter game name: ").strip()

    if not search_term:
        print("Warning: Search term cannot be blank.")
        return

    matching_games = [
        game
        for game in games
        if search_term.lower() in game["name"].lower()
    ]

    if not matching_games:
        print(f'Game not found: "{search_term}"')
        return

    print("\nSEARCH RESULTS")
    print("-" * 72)

    for number, game in enumerate(matching_games, start=1):
        print(
            f"{number}. {game['name']} | "
            f"Rating: {game['rating']:.1f} | "
            f"Genre: {game['genre']} | "
            f"Platform: {game['platform']}"
        )


def view_statistics():
    """Calculate and display statistics from the local dataset."""
    total_games = len(games)
    total_rating = sum(game["rating"] for game in games)
    average_rating = total_rating / total_games if total_games else 0
    highest_rating = max(
        (game["rating"] for game in games),
        default=0,
    )

    print("\nGAME STATISTICS")
    print("-" * 40)
    print(f"Total Games: {total_games}")
    print(f"Average Rating: {average_rating:.2f}")
    print(f"Highest Rating: {highest_rating:.1f}")
    print(
        "Note: These statistics come from the "
        "Sprint 1 local sample dataset."
    )


def view_genres():
    """Count and display the number of games in each genre."""
    genre_counts = {}

    for game in games:
        genre = game["genre"]
        genre_counts[genre] = genre_counts.get(genre, 0) + 1

    print("\nGAME GENRES")
    print("-" * 40)

    for genre in sorted(genre_counts):
        print(f"{genre}: {genre_counts[genre]} game(s)")


def view_top_games():
    """Display games sorted from highest to lowest rating."""
    sorted_games = sorted(
        games,
        key=lambda game: game["rating"],
        reverse=True,
    )

    print("\nTOP RATED GAMES")
    print("-" * 40)

    for number, game in enumerate(sorted_games, start=1):
        print(f"{number}. {game['name']} - {game['rating']:.1f}")


def main():
    """Run the Gaming Statistics Dashboard menu loop."""
    display_welcome_message()

    while True:
        display_main_menu()
        choice = get_menu_choice()

        if choice is None:
            continue

        if choice == 1:
            view_games()
        elif choice == 2:
            search_game()
        elif choice == 3:
            view_statistics()
        elif choice == 4:
            view_genres()
        elif choice == 5:
            view_top_games()
        elif choice == 0:
            print("\nThank you for using Gaming Statistics Dashboard.")
            print("Goodbye!")
            break


# Run this manually in another Colab cell:
# main()

# %%
# Run this cell manually to start the Sprint 1 CLI demo.
main()
# Out:
# ...
#              GAMING STATISTICS DASHBOARD
# ...
#
# 1. View Games
# 2. Search Game
# 3. View Statistics
# 4. View Genres
# 5. View Top Rated Games
# 0. Exit
#
# Select an option: 1
#
# GAMES
# ------------------------------------------------------------------------
# 1. Portal 2 | Rating: 4.6 | Genre: Puzzle | Platform: PC
# 2. The Witcher 3 | Rating: 4.8 | Genre: RPG | Platform: PC
# 3. Minecraft | Rating: 4.5 | Genre: Sandbox | Platform: Multi-platform
# 4. Hades | Rating: 4.7 | Genre: Action | Platform: Nintendo Switch
# 5. God of War | Rating: 4.7 | Genre: Action | Platform: PlayStation
# 6. Stardew Valley | Rating: 4.4 | Genre: Simulation | Platform: PC
# 7. Mario Kart 8 Deluxe | Rating: 4.5 | Genre: Racing | Platform: Nintendo Switch
# 8. Baldur's Gate 3 | Rating: 4.9 | Genre: RPG | Platform: PC
#
# 1. View Games
# 2. Search Game
# 3. View Statistics
# 4. View Genres
# 5. View Top Rated Games
# 0. Exit
#
# Select an option: 2
#
# Enter game name: Minecraft
#
# SEARCH RESULTS
# ...

# %% [markdown]
# ---
#
# # Sprint 1 — QA & Debugging Report
#
# ## วัตถุประสงค์ของการทดสอบ
#
# การทดสอบ Sprint 1 มีวัตถุประสงค์เพื่อตรวจสอบว่า CLI
# สามารถทำงานได้อย่างถูกต้องทั้งในกรณี Input ปกติและ Input ที่ไม่ถูกต้อง
# รวมถึงตรวจสอบว่า Input ที่ผิดไม่ทำให้โปรแกรม Crash
#
# ---
#
# | No. | Test Case | Input / Action | Expected Result | Actual Result | Status |
# |---|---|---|---|---|---|
# | 1 | Application Start | Run `main()` | แสดง Welcome Screen และ Main Menu | แสดง Welcome Screen และ Main Menu ได้ถูกต้อง | PASS |
# | 2 | View Games | `1` | แสดงรายการเกม | แสดงเกมตัวอย่างทั้ง 8 เกมได้ถูกต้อง | PASS |
# | 3 | Valid Search | `Portal` | แสดง Portal 2 | แสดง Portal 2 ได้ถูกต้อง | PASS |
# | 4 | Case-Insensitive Search | `portal` | แสดง Portal 2 | แสดง Portal 2 ได้ถูกต้องโดยไม่สนตัวพิมพ์เล็ก-ใหญ่ | PASS |
# | 5 | View Statistics | `3` | แสดง Statistics | แสดง Total Games = 8, Average Rating = 4.64 และ Highest Rating = 4.9 | PASS |
# | 6 | View Genres | `4` | แสดง Genre Summary | แสดง Genre Summary ได้ถูกต้อง | PASS |
# | 7 | View Top Games | `5` | แสดงเกมเรียงตาม Rating | แสดงเกมเรียงจาก Rating สูงสุดไปต่ำสุดได้ถูกต้อง | PASS |
# | 8 | Invalid Number | `99` | แสดงคำเตือนและกลับ Main Menu | แสดงคำเตือนและกลับ Main Menu ได้ | PASS |
# | 9 | Negative Number | `-1` | แสดงคำเตือนและกลับ Main Menu | แสดงคำเตือนและกลับ Main Menu ได้ | PASS |
# | 10 | Text Menu Input | `abc` | แสดงคำเตือนและโปรแกรมไม่ Crash | แสดงคำเตือนและโปรแกรมทำงานต่อได้ | PASS |
# | 11 | Blank Menu Input | blank | แสดงคำเตือนและโปรแกรมไม่ Crash | แสดงคำเตือนและกลับ Main Menu ได้ | PASS |
# | 12 | Empty Search | blank | แสดง Search Warning | แสดงคำเตือนสำหรับ Search Input ที่ว่าง | PASS |
# | 13 | Unknown Game | `XYZXYZ` | แสดงข้อความ "Game not found" | แสดงข้อความ Game not found ได้ถูกต้อง | PASS |
# | 14 | Exit | `0` | แสดงข้อความอำลาและออกจากโปรแกรม | แสดงข้อความอำลาและจบการทำงานของโปรแกรมได้ถูกต้อง | PASS |

# %% [markdown]
# ---
#
# # Sprint 1 — Result Report & Retrospective
#
# ## Project
# **Gaming Statistics Dashboard**
#
# ## Sprint
# **Sprint 1 — Front-End CLI Development**
#
# ---
#
# ## Team Roles
#
# - **Planner:** คิม
# - **Coder:** ฟลุ๊ค
# - **Debugger:** ออม
#
# ---
#
# # Sprint Progress Summary
#
# - [x] กำหนด Sprint Goal แล้ว
# - [x] กำหนดขอบเขตของ Sprint แล้ว
# - [x] กำหนด Definition of Done แล้ว
# - [x] พัฒนา CLI Welcome Screen แล้ว
# - [x] พัฒนา Main Menu แล้ว
# - [x] พัฒนาระบบ Menu Navigation แล้ว
# - [x] พัฒนา View Games แล้ว
# - [x] พัฒนา Search Game แล้ว
# - [x] พัฒนา Basic Statistics แล้ว
# - [x] พัฒนา Genre Summary แล้ว
# - [x] พัฒนา Top Rated Games แล้ว
# - [x] พัฒนา Menu Input Validation แล้ว
# - [x] พัฒนา Search Input Validation แล้ว
# - [x] Invalid Input ไม่ทำให้โปรแกรม Crash
# - [x] ทดสอบ QA Test Cases ครบแล้ว
# - [x] Review Code แล้ว
# - [x] สร้าง GitHub Repository แล้ว
# - [ ] สร้าง Pull Request แล้ว
#
# ---
#
# ## Sprint 1 Architecture
#
# ```text
# User
#   ↓
# CLI
#   ↓
# Menu Navigation
#   ↓
# Input Validation
#   ↓
# Sprint 1 Local Sample Dataset
#   ↓
# Display Result
# ```
#
# > ใน Sprint 1 ระบบใช้ Local Sample Dataset เพื่อพัฒนาและทดสอบ Front-End CLI
# > ส่วนการเชื่อมต่อ RAWG API, Database และระบบประมวลผลข้อมูลจะพัฒนาใน Sprint ถัดไป
#
# ---
#
# # Retrospective
#
# ## Wow! — สิ่งที่ทำได้ดี
#
# CLI ถูกแบ่งออกเป็นฟังก์ชันที่มีหน้าที่ชัดเจนสำหรับการแสดงเมนู การรับ User Input การค้นหา การคำนวณ Statistics การสรุป Genre และการจัดอันดับเกม
#
# ระบบ Input Validation สามารถจัดการกรณีตัวเลขที่ไม่ถูกต้อง ตัวเลขติดลบ Text Input, Blank Input และ Search Input ที่ไม่ถูกต้องได้โดยไม่ทำให้โปรแกรม Crash
#
# นอกจากนี้ การใช้ Local Sample Dataset ช่วยให้ทีมสามารถสาธิตฟังก์ชัน Front-End ของ Sprint 1 ได้ครบโดยยังไม่จำเป็นต้องเชื่อมต่อ Backend หรือ External API
#
# ---
#
# ## Whoops! — ปัญหาที่พบและแนวทางแก้ไข
#
# ### ปัญหาที่พบ
#
# ในระหว่างการพัฒนา หากผู้ใช้กรอกค่าที่ไม่ใช่ตัวเลข เช่น `abc` ในช่อง Menu Choice โปรแกรมอาจเกิด `ValueError`
#
# ### สาเหตุ
#
# ในเวอร์ชันแรกมีการแปลง User Input เป็น Integer โดยตรง โดยยังไม่มีการจัดการกรณี Input ที่ไม่ใช่ตัวเลข
#
# ### วิธีแก้ไข
#
# เพิ่มการตรวจสอบ Input ด้วย:
#
# - `.strip()`
# - `try-except ValueError`
# - การตรวจสอบช่วงของ Menu Choice
#
# รวมถึงเพิ่ม Validation สำหรับ Search Input ที่เป็นค่าว่าง
#
# ### ผลลัพธ์
#
# หลังจากแก้ไขแล้ว โปรแกรมสามารถรองรับกรณี:
#
# - Text Input
# - Blank Input
# - Negative Number
# - Menu Option ที่อยู่นอกช่วง
# - Empty Search
#
# ได้โดยไม่ทำให้โปรแกรม Crash และสามารถกลับไปยัง Main Menu เพื่อทำงานต่อได้
#
# ---
#
# # Sprint 1 Learning Summary
#
# ใน Sprint 1 ทีมได้เรียนรู้การออกแบบ Python CLI โดยแบ่งโปรแกรมออกเป็นฟังก์ชันขนาดเล็กที่มีหน้าที่ชัดเจน
#
# ทีมได้เรียนรู้ความสำคัญของ Input Validation และ Exception Handling เนื่องจาก User Input ไม่จำเป็นต้องถูกต้องเสมอไป
#
# การทดสอบทั้ง Normal Cases และ Edge Cases ช่วยให้ทีมสามารถตรวจสอบได้ว่าแอปพลิเคชันมีความเสถียรและทำงานได้ตาม Functional Requirements ที่กำหนดไว้
#
# นอกจากนี้ Sprint 1 ยังช่วยให้ทีมได้ฝึก Workflow การพัฒนาซอฟต์แวร์แบบแบ่งบทบาทระหว่าง Planner, Coder และ Debugger รวมถึงการเตรียมงานสำหรับส่งผ่าน GitHub
#
# ---
#
# # GitHub Submission
#
# **Repository:**
# https://github.com/Phanuwatphk/Gaming-Statistics-Dashboard.git
#
# **Pull Request:**
# https://github.com/Phanuwatphk/Gaming-Statistics-Dashboard/pull/2
#
# ---
#
# # Sprint 1 Final Status
#
# **SPRINT 1 STATUS: READY FOR PULL REQUEST**
#
# ตัวระบบ Sprint 1 ได้รับการพัฒนา ทดสอบ และ Review ตาม Requirements ที่กำหนดไว้แล้ว
#
# ขั้นตอนที่เหลือคือการสร้าง Pull Request และเพิ่ม Pull Request URL ในส่วน GitHub Submission ก่อนส่งงานฉบับสมบูรณ์
